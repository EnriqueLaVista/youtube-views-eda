# %%
import pandas as pd
import matplotlib.pyplot as plt

df_path = 'archive/Aggregated_Metrics_By_Country_And_Subscriber_Status.csv'
df = pd.read_csv(df_path)

# %%
df.head()
# Out:
#                                          Video Title External Video ID  \
# 0  🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# 1  🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# 2  🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# 3  🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# 4  🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
#
#    Video Length                                    Thumbnail link  \
# 0            59  https://i.ytimg.com/vi/OtqQYqRNDGI/hqdefault.jpg
# 1            59  https://i.ytimg.com/vi/OtqQYqRNDGI/hqdefault.jpg
# 2            59  https://i.ytimg.com/vi/OtqQYqRNDGI/hqdefault.jpg
# 3            59  https://i.ytimg.com/vi/OtqQYqRNDGI/hqdefault.jpg
# 4            59  https://i.ytimg.com/vi/OtqQYqRNDGI/hqdefault.jpg
#
#   Country Code  Is Subscribed  Views  Video Likes Added  Video Dislikes Added  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55292 entries, 0 to 55291
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Video Title                 55292 non-null  object
#  1   External Video ID           55292 non-null  object
#  2   Video Length                55292 non-null  int64
#  3   Thumbnail link              55292 non-null  object
#  4   Country Code                54906 non-null  object
#  5   Is Subscribed               55292 non-null  bool
#  6   Views                       55292 non-null  int64
#  7   Video Likes Added           55292 non-null  int64
#  8   Video Dislikes Added        55292 non-null  int64
#  9   Video Likes Removed         55292 non-null  int64
#  10  User Subscriptions Added    55292 non-null  int64
#  11  User Subscriptions Removed  55292 non-null  int64
#  12  Average View Percentage     53854 non-null  float64
# ...

# %%
df.describe()
# Out:
#        Video Length          Views  Video Likes Added  Video Dislikes Added  \
# count  55292.000000   55292.000000       55292.000000          55292.000000
# mean     896.678073     100.573157           4.239311              0.106055
# std      927.380801    1704.966002          65.291451              2.507351
# min       47.000000       0.000000           0.000000              0.000000
# 25%      375.000000       2.000000           0.000000              0.000000
# 50%      545.000000       7.000000           0.000000              0.000000
# 75%      934.000000      27.000000           1.000000              0.000000
# max     5029.000000  285593.000000        9165.000000            399.000000
#
#        Video Likes Removed  User Subscriptions Added  \
# count         55292.000000              55292.000000
# mean              0.175577                  2.365279
# std               3.601171                 65.889539
# min               0.000000                  0.000000
# ...

# %%
# Look at null values

df[df.isnull().any(axis=1)]
# Out:
#                                              Video Title External Video ID  \
# 103    🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# 183    🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# 193    🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# 211    🌶 Hot Topics in Tech: Data Science Explained #...       OtqQYqRNDGI
# 264      git for Data Science Made Simple... (Hopefully)       _0rHU6qAQe0
# ...                                                  ...               ...
# 55150                #66DaysOfData - 3 Reasons to Start!       sICJ6a2wX5g
# 55178                #66DaysOfData - 3 Reasons to Start!       sICJ6a2wX5g
# 55212                #66DaysOfData - 3 Reasons to Start!       sICJ6a2wX5g
# 55235                #66DaysOfData - 3 Reasons to Start!       sICJ6a2wX5g
# 55249                #66DaysOfData - 3 Reasons to Start!       sICJ6a2wX5g
#
# ...

# %%
# Drop unwated columns. Likes removed is not of interest. User comments are all zero

df_sub = df.drop(['Video Likes Removed', 'User Comments Added'], axis=1)

# %%
# Drop unwated rows

#df_sub = df_sub.drop(df_sub[df_sub['Country Code'] == ''].index)

df_sub = df_sub.dropna()

# %%
df_sub.describe()
# Out:
#        Video Length          Views  Video Likes Added  Video Dislikes Added  \
# count  53658.000000   53658.000000       53658.000000          53658.000000
# mean     892.650024     103.611596           4.366842              0.109192
# std      923.172407    1730.640762          66.273947              2.545159
# min       47.000000       1.000000           0.000000              0.000000
# 25%      375.000000       2.000000           0.000000              0.000000
# 50%      545.000000       7.000000           0.000000              0.000000
# 75%      917.000000      29.000000           1.000000              0.000000
# max     5029.000000  285593.000000        9165.000000            399.000000
#
#        User Subscriptions Added  User Subscriptions Removed  \
# count              53658.000000                53658.000000
# mean                   2.431809                    0.054847
# std                   66.884082                    0.778382
# ...

# %%
# Find how many unique videos are in the dataset

df_sub['Video Title'].nunique()
# Out:
# 223

# %%
# Find how many unique countries are in the dataset

df_sub['Country Code'].nunique()
# Out:
# 232

# %%
# Look at general watch time by video length

# %%
# Compare watch time of subscribers against non subscribers
